# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import display
import optosim

# %%
ConvFactorArray = [1.8e5, 1.8e5, 1.8e5]

# %%
dat = optosim.SimData([0, 1e-2], 5e6, [75e3, 160e3, 180e3], 4000.0, 3.1e-19, ConvFactorArray, 1e-30, dt=1e-9)
# Out:
# solving...
# solving...
# solving...
# /Users/ajs3g11/anaconda/envs/python3/lib/python3.6/site-packages/scipy/signal/spectral.py:772: UserWarning: nperseg = 1000000, is greater than input length = 50000, using nperseg = 50000
#   'using nperseg = {1:d}'.format(nperseg, x.shape[-1]))

# %%
# tArray = dat.sde_solvers[0].tArray.get_array()

# fig,ax = plt.subplots()
# ax.plot(tArray, dat.sde_solvers[0].q)
# ax.plot(tArray, dat.sde_solvers[1].q)
# ax.plot(tArray, dat.sde_solvers[2].q)

# %%
dat.plot_PSD([0, 300])
# Out:
# (<matplotlib.figure.Figure at 0x115751f98>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11963fd68>)

# %%
dat.extract_ZXY_motion?

# %%
z, x, y, t, fig, ax = dat.extract_ZXY_motion([75e3, 160e3, 180e3], 3e3, [10e3, 5e3, 5e3], subSampleFraction=2)
# Out:
# filtering Z
# filtering X
# filtering Y
# /Users/ajs3g11/anaconda/envs/python3/lib/python3.6/site-packages/scipy/signal/spectral.py:772: UserWarning: nperseg = 1000000, is greater than input length = 25000, using nperseg = 25000
#   'using nperseg = {1:d}'.format(nperseg, x.shape[-1]))

# %%
t, z, vz = dat.calc_phase_space(75e3, ConvFactorArray[0], FractionOfSampleFreq=2)
t, x, vx = dat.calc_phase_space(160e3, ConvFactorArray[1], FractionOfSampleFreq=2)
t, y, vy = dat.calc_phase_space(180e3, ConvFactorArray[2], FractionOfSampleFreq=2)
# Out:
# filtering data
# filtering data
# filtering data

# %%
TimeTuple = [500e-6, 1000e-6]
alpha=0.8

# %%
plt.plot(t, z, alpha=alpha)
plt.plot(dat.simtime.get_array(), dat.TrueSignals[0, 0], alpha=alpha)
plt.xlim(TimeTuple)
# Out:
# (0.0005, 0.001)

# %%
plt.plot(t[1:], vz, alpha=alpha)
plt.plot(dat.simtime.get_array(), dat.TrueSignals[0, 1], alpha=alpha)
plt.xlim(TimeTuple)
# Out:
# (0.0005, 0.001)

# %%
plt.plot(t, x, alpha=alpha)
plt.plot(dat.simtime.get_array(), dat.TrueSignals[1, 0], alpha=alpha)
plt.xlim(TimeTuple)
# Out:
# (0.0005, 0.001)

# %%
plt.plot(t[1:], vx, alpha=alpha)
plt.plot(dat.simtime.get_array(), dat.TrueSignals[1, 1], alpha=alpha)
plt.xlim(TimeTuple)
# Out:
# (0.0005, 0.001)

# %%
plt.plot(t, y, alpha=alpha)
plt.plot(dat.simtime.get_array(), dat.TrueSignals[2, 0], alpha=alpha)
plt.xlim(TimeTuple)
# Out:
# (0.0005, 0.001)

# %%
plt.plot(t[1:], vy, alpha=alpha)
plt.plot(dat.simtime.get_array(), dat.TrueSignals[2, 1], alpha=alpha)
plt.xlim(TimeTuple)
# Out:
# (0.0005, 0.001)

# %%
dat.get_fit_auto(75e3)
# Out:
# /Users/ajs3g11/anaconda/envs/python3/lib/python3.6/site-packages/optoanalysis-3.3.9-py3.6-macosx-10.7-x86_64.egg/optoanalysis/optoanalysis.py:515: UserWarning: range is too small to fit, returning NaN
#   _warnings.warn("range is too small to fit, returning NaN", UserWarning)
# found best
# A: 4631857631633.951 +- 20.126819651571832%
# Trap Frequency: 471961.4176615617 +- 0.11645868305855983%
# Big Gamma: 1910.569230695763 +- 47.535905213772054%
# (471961.4176615617+/-549.640051553164,
#  4631857631633.951+/-932245632036.5319,
#  1910.569230695763+/-908.2063785470319,
#  <matplotlib.figure.Figure at 0x1156015f8>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x117083780>)
