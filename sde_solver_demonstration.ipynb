# %%
# %matplotlib inline

# %%
import optosim.sde_solver as sde_solver

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Gamma0 = 4000 # radians/second
Omega0 = 75e3*2*np.pi # radians/second
eta = 0.0
T_0 = 300 # K
m = 3.1e-19 # KG

# %%
sim1 = sde_solver.sde_solver(Omega0, Gamma0, 0, m, seed=88, TimeTuple=[0, 100e-6])

# %%
sim1.solve()
# Out:
# (array([  0.00000000e+00,   0.00000000e+00,   3.49446161e-14, ...,
#          -1.28754836e-07,  -1.28757203e-07,  -1.28759676e-07]),
#  array([  0.00000000e+00,   3.49446161e-05,   7.56110858e-04, ...,
#          -2.36784486e-03,  -2.47279724e-03,  -2.23319248e-03]))

# %%
# %timeit sim1.solve();
# Out:
# The slowest run took 5.92 times longer than the fastest. This could mean that an intermediate result is being cached.
# 100 loops, best of 3: 2.33 ms per loop

# %%
plt.plot(sim1.tArray.get_array()*1e6, sim1.q*1e9)
plt.xlabel("t (us)")
plt.ylabel("q (nm)")

# %%
plt.plot(sim1.tArray.get_array()*1e6, sim1.v)
plt.xlabel("t (us)")
plt.ylabel("v (m/s)")
